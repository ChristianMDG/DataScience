# %%
import pandas as pd

# %%
data_csv = pd.read_csv('clients.csv')
data_csv.head()

# %%
data_json = pd.read_json('clients.json')
data_json.head()
data_json.shape

# %%
data_excel = pd.read_excel('clients.xlsx')

#afficher la forme du DataFrame
data_excel.shape
#transformer le DataFrame en array numpy
data_excel.values
#afficher les 5 premières lignes
data_excel.head()

# %%
#extraire la colonne email
email = data_excel["email"]
#afficher les 5 premières lignes de la colonne email
email.head()

# %%
#extraire plusieurs colonnes
variables = ['email','nom']
#afficher les 5 premières lignes des colonnes extraites
data_excel[variables].head()

# %%
#autre méthode pour extraire plusieurs colonnes
data_excel[['nom', 'email']].head()

# %%
#extraire une seule colonne
data = data_excel['nom']
#afficher son types
type(data)

#type(data_excel['nom'])

# %% [markdown]
# ### Créez et supprimez une colonne

# %%
#modifier une colonne
data_excel['argent'] = 15000

# %%
#modifier une colonne
data_excel['identifiant'] = data_excel['identifiant']*100
data_excel.head()

# %%
#supprimer une colonne
#data_excel.drop(columns=['argent'])
#del data_excel['argent']
#data_excel.pop('argent')

# %% [markdown]
# ### Renommez une colonne

# %%
#renommer une colonne
data = data_excel.rename(columns={'nom' : 'Name'})
data.head()

# %%
#renommer plusieurs colonnes
data = data_excel.rename(columns={'nom' : 'Name', 'email' : 'Email_Address'})
data.head()

# %% [markdown]
# ### Changez le type d’une colonne

# %%
data_excel['identifiant'].astype(float)

# %% [markdown]
# ### Triez un data frame

# %%
# trier selon l’identifiant, par ordre croissant :
data = data_excel.sort_values('identifiant')
data.head()

# %%
#trier selon l’identifiant par ordre décroissant :
data = data_excel.sort_values('identifiant', ascending = False)
data.head()

# %%
# trier selon le genre puis le nom, par ordre croissant :
data.sort_values(['genre', 'nom'])
data.head

# %%
clients.sort_values(['genre', 'nom'], ascending=[True, False])
