# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
prets = pd.read_csv('https://raw.githubusercontent.com/OpenClassrooms-Student-Center/fr-4452741-decouvrez-les-librairies-python-pour-la-data-science/main/data/prets.csv')
prets.head()
# Out:
#    identifiant      ville     CP  revenu  remboursement  duree        type  \
# 0            0   TOULOUSE  31100  3669.0        1130.05    240  immobilier
# 1            1      PARIS  75009  5310.0         240.00     64  automobile
# 2            1      PARIS  75009  5310.0        1247.85    300  immobilier
# 3            2  MARSEILLE  13010  1873.0         552.54    240  immobilier
# 4            3  MARSEILLE  13010  1684.0         586.03    180  immobilier
#
#     taux
# 0  1.168
# 1  3.701
# 2  1.173
# 3  0.972
# 4  1.014

# %% [markdown]
# # Le nuage de points

# %%
plt.scatter(prets['revenu'], prets['taux'])

# %%
plt.scatter(prets['revenu'], prets['taux'],
    s=60, alpha=0.5, c='red', marker='P')

# %% [markdown]
# # Le diagramme circulaire

# %%
data = prets.groupby('ville')['remboursement'].sum()
data = data.reset_index()

# %%
plt.pie(x=data['remboursement'], labels=data['ville'])
# Out:
# ([<matplotlib.patches.Wedge at 0x7fbd03d49d10>,
#   <matplotlib.patches.Wedge at 0x7fbd03ec0210>,
#   <matplotlib.patches.Wedge at 0x7fbd03d6f2d0>,
#   <matplotlib.patches.Wedge at 0x7fbd03d7c510>,
#   <matplotlib.patches.Wedge at 0x7fbd03d7d690>,
#   <matplotlib.patches.Wedge at 0x7fbd03d7eb10>],
#  [Text(1.0735482881610743, 0.23977921716951908, 'BORDEAUX'),
#   Text(0.7559779757294925, 0.7990602606887286, 'LYON'),
#   Text(-0.2207948127606491, 1.0776129410219561, 'MARSEILLE'),
#   Text(-0.9928563382020422, 0.47353594551209344, 'NICE'),
#   Text(-0.35667747630629365, -1.040567719034073, 'PARIS'),
#   Text(1.058235353672122, -0.3002298057129555, 'TOULOUSE')])

# %%
plt.pie(x=data['remboursement'], labels=data['ville'], autopct='%.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7fbd03dc6710>,
#   <matplotlib.patches.Wedge at 0x7fbd03c15b50>,
#   <matplotlib.patches.Wedge at 0x7fbd03c17a10>,
#   <matplotlib.patches.Wedge at 0x7fbd03c17090>,
#   <matplotlib.patches.Wedge at 0x7fbd03c27290>,
#   <matplotlib.patches.Wedge at 0x7fbd03c35790>],
#  [Text(1.0735482881610743, 0.23977921716951908, 'BORDEAUX'),
#   Text(0.7559779757294925, 0.7990602606887286, 'LYON'),
#   Text(-0.2207948127606491, 1.0776129410219561, 'MARSEILLE'),
#   Text(-0.9928563382020422, 0.47353594551209344, 'NICE'),
#   Text(-0.35667747630629365, -1.040567719034073, 'PARIS'),
#   Text(1.058235353672122, -0.3002298057129555, 'TOULOUSE')],
#  [Text(0.5855717935424041, 0.13078866391064675, '6.99%'),
#   Text(0.41235162312517776, 0.435851051284761, '11.89%'),
#   Text(-0.12043353423308131, 0.587788876921067, '18.66%'),
#   Text(-0.5415580026556593, 0.2582923339156873, '10.74%'),
#   Text(-0.19455135071252377, -0.5675823922004034, '42.91%'),
#   Text(0.5772192838211574, -0.16376171220706662, '8.80%')])

# %% [markdown]
# ## Le diagramme à barres

# %%
plt.bar(height=data['remboursement'], x=data['ville'])
# Out:
# <BarContainer object of 6 artists>

# %% [markdown]
# ordonner du plus grand au plus petit

# %%
data_sorted = data.sort_values('remboursement', ascending=False)
plt.bar(height=data_sorted['remboursement'], x=data_sorted['ville'])
# Out:
# <BarContainer object of 6 artists>

# %% [markdown]
# ## L’histogramme

# %%
plt.hist(prets['revenu'])
# Out:
# (array([38., 42., 43., 27., 31., 17., 10., 11., 15., 10.]),
#  array([1200. , 1760.7, 2321.4, 2882.1, 3442.8, 4003.5, 4564.2, 5124.9,
#         5685.6, 6246.3, 6807. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## Les courbes

# %%
plt.plot(evolution_ca['date'], evolution_ca["chiffre d'affaire"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 plt.plot(evolution_ca['date'], evolution_ca["chiffre d'affaire"])
#
# NameError: name 'evolution_ca' is not defined
